# %% [markdown]
# <a href="https://colab.research.google.com/github/wohecha/HuggingFace-Unit1/blob/main/notebooks/unit7-MARL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# # A2A Agent to agent.
# ---
# based on:
# https://huggingface.co/learn/deep-rl-course/unit7/hands-on
